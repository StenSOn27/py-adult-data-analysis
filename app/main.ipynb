# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 0
# Read the dataset from csv file & perform data cleaning - remove all rows, which contains `?` in some columns.
# Also check for data correctness (salary & salary $K).

# %%
df = pd.read_csv("../data/adult.csv")

df.replace('?', np.nan).dropna()
# Out:
#        Unnamed: 0  age         workclass   education      marital-status  \
# 0               0   39         State-gov   Bachelors       Never-married
# 1               1   50  Self-emp-not-inc   Bachelors  Married-civ-spouse
# 2               2   38           Private     HS-grad            Divorced
# 3               3   53           Private        11th  Married-civ-spouse
# 4               4   28           Private   Bachelors  Married-civ-spouse
# ...           ...  ...               ...         ...                 ...
# 32556       32556   27           Private  Assoc-acdm  Married-civ-spouse
# 32557       32557   40           Private     HS-grad  Married-civ-spouse
# 32558       32558   58           Private     HS-grad             Widowed
# 32559       32559   22           Private     HS-grad       Never-married
# 32560       32560   52      Self-emp-inc     HS-grad  Married-civ-spouse
#
#               occupation   relationship   race     sex  hours-per-week  \
# 0           Adm-clerical  Not-in-family  White    Male              40
# 1        Exec-managerial        Husband  White    Male              13
# 2      Handlers-cleaners  Not-in-family  White    Male              40
# 3      Handlers-cleaners        Husband  Black    Male              40
# 4         Prof-specialty           Wife  Black  Female              40
# ...                  ...            ...    ...     ...             ...
# 32556       Tech-support           Wife  White  Female              38
# 32557  Machine-op-inspct        Husband  White    Male              40
# 32558       Adm-clerical      Unmarried  White  Female              40
# 32559       Adm-clerical      Own-child  White    Male              20
# 32560    Exec-managerial           Wife  White  Female              40
#
#       native-country salary  salary K$
# 0      United-States  <=50K         39
# 1      United-States  <=50K         35
# 2      United-States  <=50K         27
# 3      United-States  <=50K         43
# 4               Cuba  <=50K         25
# ...              ...    ...        ...
# 32556  United-States  <=50K         36
# 32557  United-States   >50K        173
# 32558  United-States  <=50K         40
# 32559  United-States  <=50K         38
# 32560  United-States   >50K        243
#
# [30162 rows x 13 columns]

# %% [markdown]
# # Task 1
# Print the count of men and women in the dataset.

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %% [markdown]
# # Task 2
# Find the average age of men in dataset

# %%
df[df['sex'] == 'Male']['age'].mean()
# Out:
# np.float64(39.43354749885268)

# %% [markdown]
# # Task 3
# Get the percentage of people from Poland (native-country)

# %%
(df['native-country'] == 'Poland').mean() * 100
# Out:
# np.float64(0.18426952489174164)

# %% [markdown]
# # Task 4
# Get the mean and standard deviation of the age for people who earn > 50K per year. After this, get it for those who earn <= 50K.

# %%
df[df["salary"] == "<=50K"]["age"].agg(['mean', 'std'])
# Out:
# mean    36.783738
# std     14.020088
# Name: age, dtype: float64

# %%
df[df["salary"] == ">50K"]["age"].agg(['mean', 'std'])
# Out:
# mean    44.249841
# std     10.519028
# Name: age, dtype: float64

# %% [markdown]
# # Task 5
# Check, if there are some people without higher education (education: Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters, Doctorate), but with > 50K salary

# %%
higher_education_mask = df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])
df_higher_edu = df[higher_education_mask]
df_higher_edu
# Out:
#        Unnamed: 0  age         workclass  education      marital-status  \
# 0               0   39         State-gov  Bachelors       Never-married
# 1               1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse
# 4               4   28           Private  Bachelors  Married-civ-spouse
# 5               5   37           Private    Masters  Married-civ-spouse
# 8               8   31           Private    Masters       Never-married
# ...           ...  ...               ...        ...                 ...
# 32538       32538   38           Private  Bachelors            Divorced
# 32539       32539   71                 ?  Doctorate  Married-civ-spouse
# 32544       32544   31           Private    Masters            Divorced
# 32553       32553   32           Private    Masters       Never-married
# 32554       32554   53           Private    Masters  Married-civ-spouse
#
#             occupation   relationship                race     sex  \
# 0         Adm-clerical  Not-in-family               White    Male
# 1      Exec-managerial        Husband               White    Male
# 4       Prof-specialty           Wife               Black  Female
# 5      Exec-managerial           Wife               White  Female
# 8       Prof-specialty  Not-in-family               White  Female
# ...                ...            ...                 ...     ...
# 32538   Prof-specialty      Unmarried               Black  Female
# 32539                ?        Husband               White    Male
# 32544    Other-service  Not-in-family               Other  Female
# 32553     Tech-support  Not-in-family  Asian-Pac-Islander    Male
# 32554  Exec-managerial        Husband               White    Male
#
#        hours-per-week native-country salary  salary K$
# 0                  40  United-States  <=50K         39
# 1                  13  United-States  <=50K         35
# 4                  40           Cuba  <=50K         25
# 5                  40  United-States  <=50K         44
# 8                  50  United-States   >50K        330
# ...               ...            ...    ...        ...
# 32538              45  United-States   >50K        248
# 32539              10  United-States   >50K         62
# 32544              30  United-States  <=50K         33
# 32553              11         Taiwan  <=50K         36
# 32554              40  United-States   >50K        103
#
# [7491 rows x 13 columns]

# %% [markdown]
# # Task 6
# Get the statistics of age for each type of education. Use `groupby` and `describe` for this.

# %%
df.groupby('education')['age'].describe()
# Out:
#                 count       mean        std   min    25%   50%   75%   max
# education
# 10th            933.0  37.429796  16.720713  17.0  22.00  34.0  52.0  90.0
# 11th           1175.0  32.355745  15.545485  17.0  18.00  28.0  43.0  90.0
# 12th            433.0  32.000000  14.334625  17.0  19.00  28.0  41.0  79.0
# 1st-4th         168.0  46.142857  15.615625  19.0  33.00  46.0  57.0  90.0
# 5th-6th         333.0  42.885886  15.557285  17.0  29.00  42.0  54.0  84.0
# 7th-8th         646.0  48.445820  16.092350  17.0  34.25  50.0  61.0  90.0
# 9th             514.0  41.060311  15.946862  17.0  28.00  39.0  54.0  90.0
# Assoc-acdm     1067.0  37.381443  11.095177  19.0  29.00  36.0  44.0  90.0
# Assoc-voc      1382.0  38.553546  11.631300  19.0  30.00  37.0  46.0  84.0
# Bachelors      5355.0  38.904949  11.912210  19.0  29.00  37.0  46.0  90.0
# Doctorate       413.0  47.702179  11.784716  24.0  39.00  47.0  55.0  80.0
# HS-grad       10501.0  38.974479  13.541524  17.0  28.00  37.0  48.0  90.0
# Masters        1723.0  44.049913  11.068935  18.0  36.00  43.0  51.0  90.0
# Preschool        51.0  42.764706  15.126914  19.0  31.00  41.0  53.5  75.0
# Prof-school     576.0  44.746528  11.962477  25.0  36.00  43.0  51.0  90.0
# Some-college   7291.0  35.756275  13.474051  17.0  24.00  34.0  45.0  90.0

# %% [markdown]
# # Task 7
# Compare the married and non-married men salaries. Who earns more? (>50K or <=50K)
# Married men are those, whom `marital-status` starts with "Married". Others are not.

# %%
male_df = df[df['sex'] == 'Male']
male_df.groupby(male_df['marital-status'].str.startswith('Married'))['salary'].value_counts(normalize=True)
# Out:
# marital-status  salary
# False           <=50K     0.915505
#                 >50K      0.084495
# True            <=50K     0.559486
#                 >50K      0.440514
# Name: proportion, dtype: float64

# %% [markdown]
# # Task 8
# Get the max hours per week some person works. How many people works the same amount of hours per week?

# %%
df['hours-per-week'].max()
# Out:
# np.float64(39.43354749885268)

# %%
(df['hours-per-week'] == df['hours-per-week'].max()).sum()
# Out:
# np.int64(85)

# %% [markdown]
# # Task 9
# Analyze the correlation between data in dataset. Understand connected fields in it and print highlight thier connection.

# %%
corr = df.corr(numeric_only=True)

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8bcdc_row0_col0, #T_8bcdc_row1_col1, #T_8bcdc_row2_col2, #T_8bcdc_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8bcdc_row0_col1, #T_8bcdc_row0_col2, #T_8bcdc_row0_col3, #T_8bcdc_row1_col0, #T_8bcdc_row2_col0, #T_8bcdc_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8bcdc_row1_col2, #T_8bcdc_row2_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8bcdc_row1_col3, #T_8bcdc_row3_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_8bcdc_row2_col3, #T_8bcdc_row3_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8bcdc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bcdc_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_8bcdc_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_8bcdc_level0_col2" class="col_heading level0 col2" >hours-per-week</th>
#       <th id="T_8bcdc_level0_col3" class="col_heading level0 col3" >salary K$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bcdc_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_8bcdc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8bcdc_row0_col1" class="data row0 col1" >0.001286</td>
#       <td id="T_8bcdc_row0_col2" class="data row0 col2" >0.000607</td>
#       <td id="T_8bcdc_row0_col3" class="data row0 col3" >-0.001666</td>
#     </tr>
#     <tr>
#       <th id="T_8bcdc_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_8bcdc_row1_col0" class="data row1 col0" >0.001286</td>
#       <td id="T_8bcdc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8bcdc_row1_col2" class="data row1 col2" >0.068756</td>
#       <td id="T_8bcdc_row1_col3" class="data row1 col3" >0.201774</td>
#     </tr>
#     <tr>
#       <th id="T_8bcdc_level0_row2" class="row_heading level0 row2" >hours-per-week</th>
#       <td id="T_8bcdc_row2_col0" class="data row2 col0" >0.000607</td>
#       <td id="T_8bcdc_row2_col1" class="data row2 col1" >0.068756</td>
#       <td id="T_8bcdc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8bcdc_row2_col3" class="data row2 col3" >0.196916</td>
#     </tr>
#     <tr>
#       <th id="T_8bcdc_level0_row3" class="row_heading level0 row3" >salary K$</th>
#       <td id="T_8bcdc_row3_col0" class="data row3 col0" >-0.001666</td>
#       <td id="T_8bcdc_row3_col1" class="data row3 col1" >0.201774</td>
#       <td id="T_8bcdc_row3_col2" class="data row3 col2" >0.196916</td>
#       <td id="T_8bcdc_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
